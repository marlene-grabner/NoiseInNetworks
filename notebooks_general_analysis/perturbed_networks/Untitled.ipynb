# %%
import networkx as nx
import pandas as pd

# %%
file_path = "lisc/data/work/menche/marlene/NoiseInNetworks/data/perturbed_networks/test_network/perturbed_hub_target/test_targeted_hub_addition_noise_0p05.parquet"
df = pd.read_parquet(file_path)

# If you print it, you'll see your "source", "target", and "repeat" columns
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 file_path = "lisc/data/work/menche/marlene/NoiseInNetworks/data/perturbed_networks/test_network/perturbed_hub_target/test_targeted_hub_addition_noise_0p05.parquet"
# ----> 2 df = pd.read_parquet(file_path)
#       3
#       4 # If you print it, you'll see your "source", "target", and "repeat" columns
#       5 print(df.head())
#
# File /lisc/opt/sw/software/Conda/Miniforge3/envs/JupyterHub-5.4.6/lib/python3.11/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
# ...
